# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the Parquet file
df_ori = pd.read_parquet('ekubo_market_depth_dataset.parquet')

# %%
# An overview of the dataframe structure:
df_ori.head()
# Out:
#   BLOCK_NUMBER     BLOCK_TIMESTAMP  \
# 0       328311 2023-10-16 15:58:15
# 1       328253 2023-10-16 15:05:36
# 2       328269 2023-10-16 15:23:34
# 3       328545 2023-10-16 20:56:28
# 4       328205 2023-10-16 13:42:10
#
#                                              TX_HASH                 TX_ID  \
# 0  0x068ae08b780c44b6d5674540a49bbda991410bcd3ae8...   5461067_0_328311_98
# 1  0x00bdc788d3ce6493eb7adefba441fe4e044a21d1d0f6...  5461067_0_328253_212
# 2  0x03b06aff66afbc79d2e5c2a48919d4c773ef589e7ead...  5461067_0_328269_137
# 3  0x034398a7788f3a78c60956da2d128c56b21491b36f0e...  5461067_0_328545_149
# 4  0x051ca2db4564744fc6de3545e34e2f623a302d085cc1...   5461067_0_328205_41
#
#                                              POOL_ID  \
# 0  0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...
# 1  0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...
# 2  0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...
# 3  0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...
# 4  0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...
#
#                                       TOKEN0_ADDRESS  \
# 0  0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee...
# 1  0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee...
# 2  0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c...
# 3  0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c...
# 4  0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee...
#
#                                       TOKEN1_ADDRESS EVENT_NAME  \
# 0  0x068f5c6a61780768455de69077e07e89787839bf8166...       Mint
# 1  0x068f5c6a61780768455de69077e07e89787839bf8166...       Mint
# 2  0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee...       Mint
# 3  0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee...       Mint
# 4  0x068f5c6a61780768455de69077e07e89787839bf8166...       Mint
#
#                                         FROM_ADDRESS  \
# 0  0x0372a7f547471e9fa006dc945d5c10b2a80478ca7e35...
# 1  0x04e64ccbadc967b4f14b16b6015ae18a4e50026f3cd1...
# 2  0x04c7b913ce8d1d7a0bfcdad2546abfdb657958660a06...
# 3  0x05022bef5db6faded63797c25dc1834ebb7936347894...
# 4  0x054526db0dbc4db39941a6c31d90df72b4f940ef3c59...
#
#                                           TO_ADDRESS  ...  \
# 0  0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...  ...
# 1  0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...  ...
# 2  0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...  ...
# 3  0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...  ...
# 4  0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...  ...
#
#                     TOKEN0_REAL_AMOUNT TOKEN1_RAW_AMOUNT TOKEN1_DECIMALS  \
# 0    -0.079991999999999993664623332279            -80000               6
# 1   -82.087671999999997751729097217321         -82095379               6
# 2    -0.000632340897114350044931618822           -997738               6
# 3    -0.000641968862647891952248613290          -1000000               6
# 4  -105.941124000000002070009941235185        -106177367               6
#
#                     TOKEN1_REAL_AMOUNT FEE_TIER LIQUIDITY_AMOUNT  LOWER_TICK  \
# 0    -0.080000000000000001665334536938   0.0005          8039644      -20000
# 1   -82.095378999999994107383827213198   0.0005       8250270816      -20000
# 2    -0.997738000000000013756107364316   0.0005    2524377067828   -20284000
# 3    -1.000000000000000000000000000000   0.0005    2546541156515   -20279000
# 4  -106.177367000000003827153705060482   0.0005      10659047790      -20000
#
#   UPPER_TICK SWAP_TICK TICK_SPACING
# 0      20000         0         1000
# 1      20000         0         1000
# 2  -20244000         0         1000
# 3  -20239000         0         1000
# 4      20000         0         1000
#
# [5 rows x 22 columns]

# %%
# An overview of the dataframe structure:
df_ori.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3024741 entries, 0 to 3024740
# Data columns (total 22 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   BLOCK_NUMBER        object
#  1   BLOCK_TIMESTAMP     datetime64[ns]
#  2   TX_HASH             object
#  3   TX_ID               object
#  4   POOL_ID             object
#  5   TOKEN0_ADDRESS      object
#  6   TOKEN1_ADDRESS      object
#  7   EVENT_NAME          object
#  8   FROM_ADDRESS        object
#  9   TO_ADDRESS          object
#  10  TOKEN0_RAW_AMOUNT   object
#  11  TOKEN0_DECIMALS     object
#  12  TOKEN0_REAL_AMOUNT  object
#  13  TOKEN1_RAW_AMOUNT   object
#  14  TOKEN1_DECIMALS     object
#  15  TOKEN1_REAL_AMOUNT  object
#  16  FEE_TIER            float32
#  17  LIQUIDITY_AMOUNT    object
#  18  LOWER_TICK          object
#  19  UPPER_TICK          object
#  20  SWAP_TICK           object
#  21  TICK_SPACING        object
# dtypes: datetime64[ns](1), float32(1), object(20)
# memory usage: 496.2+ MB

# %%
# A quick view of the values in one randomly selected row:
df_ori.iloc[100]
# Out:
# BLOCK_NUMBER                                                     317634
# BLOCK_TIMESTAMP                                     2023-10-13 03:18:38
# TX_HASH               0x008dcce8b4d0814d1655d294aa9a6ba898ece028e317...
# TX_ID                                              5461067_0_317634_132
# POOL_ID               0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...
# TOKEN0_ADDRESS        0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee...
# TOKEN1_ADDRESS        0x068f5c6a61780768455de69077e07e89787839bf8166...
# EVENT_NAME                                                         Mint
# FROM_ADDRESS          0x057ddd233caca940b84ea0c51c3905eb9ca3f4ea31bc...
# TO_ADDRESS            0x00000005dd3d2f4429af886cd1a3b08289dbcea99a29...
# TOKEN0_RAW_AMOUNT                                            -279110619
# TOKEN0_DECIMALS                                                       6
# TOKEN0_REAL_AMOUNT                  -279.110618999999985589965945109725
# TOKEN1_RAW_AMOUNT                                            -279094071
# TOKEN1_DECIMALS                                                       6
# TOKEN1_REAL_AMOUNT                  -279.094070999999985360773280262947
# FEE_TIER                                                         0.0005
# LIQUIDITY_AMOUNT                                            28050032209
# LOWER_TICK                                                       -20000
# UPPER_TICK                                                        20000
# SWAP_TICK                                                             0
# TICK_SPACING                                                       1000
# Name: 100, dtype: object

# %%
# Total types of 'EVENT_NAME':
df_ori['EVENT_NAME'].unique()
# Out:
# array(['Mint', 'Burn', 'Swap'], dtype=object)

# %%
# Total 'TOKEN0_ADDRESS':
df_ori['TOKEN0_ADDRESS'].unique()

''' Token0 addresses:
'''
# STRK: 0x04718f5a0fc34cc1af16a1cdee98ffb20c31f5cd61d6ab07201858f4287c938d
# https://starkscan.co/token/0x04718f5a0fc34cc1af16a1cdee98ffb20c31f5cd61d6ab07201858f4287c938d

# ETH: 0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c741b1562b82f9e004dc7
# https://starkscan.co/token/0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c741b1562b82f9e004dc7

# USDC: 0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee7e0d5ebb06f3ecf368a8
# https://starkscan.co/token/0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee7e0d5ebb06f3ecf368a8
# Out:
# array(['0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee7e0d5ebb06f3ecf368a8',
#        '0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c741b1562b82f9e004dc7',
#        '0x04718f5a0fc34cc1af16a1cdee98ffb20c31f5cd61d6ab07201858f4287c938d'],
#       dtype=object)

# %%
# Total 'TOKEN1_ADDRESS':
df_ori['TOKEN1_ADDRESS'].unique()

''' Token1 addresses:
'''
# ETH: 0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c741b1562b82f9e004dc7
# https://starkscan.co/token/0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c741b1562b82f9e004dc7

# USDC: 0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee7e0d5ebb06f3ecf368a8
# https://starkscan.co/token/0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee7e0d5ebb06f3ecf368a8

# USDT: 0x068f5c6a61780768455de69077e07e89787839bf8166decfbf92b645209c0fb8
# https://starkscan.co/token/0x068f5c6a61780768455de69077e07e89787839bf8166decfbf92b645209c0fb8
# Out:
# array(['0x068f5c6a61780768455de69077e07e89787839bf8166decfbf92b645209c0fb8',
#        '0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee7e0d5ebb06f3ecf368a8',
#        '0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c741b1562b82f9e004dc7'],
#       dtype=object)

# %%
# Total 'TO_ADDRESS':
df_ori['TO_ADDRESS'].unique()

''' TO_ADDRESS:
'''
# Ekubo contract:
# https://starkscan.co/contract/0x00000005dd3d2f4429af886cd1a3b08289dbcea99a294197e9eb43b0e0325b4b
# Out:
# array(['0x00000005dd3d2f4429af886cd1a3b08289dbcea99a294197e9eb43b0e0325b4b'],
#       dtype=object)

# %%
# Total 'FROM_ADDRESS':
print('Total FROM_ADDRESS:', len(df_ori['FROM_ADDRESS'].unique()))
# Out:
# Total FROM_ADDRESS: 607125

# %%
'''
- Added names for Token0 and Token1tags
- Add tags for different pair of pools 
- Convert dataframe data types to either integer or float 
'''
df = df_ori.copy()

# Compute timestamp:
df['datetime'] = pd.to_datetime(df_ori['BLOCK_TIMESTAMP'])
df['timestamp'] = df['datetime'].astype('int64') // 10**9  # Convert nanoseconds to seconds
df = df.sort_values(by='timestamp')

# Obtain names of Token0 and Token1:

# Tag different token address:
# Token0
# ETH: 0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c741b1562b82f9e004dc7
# USDC: 0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee7e0d5ebb06f3ecf368a8
# STRK: 0x04718f5a0fc34cc1af16a1cdee98ffb20c31f5cd61d6ab07201858f4287c938d

# Token1
# ETH: 0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c741b1562b82f9e004dc7
# USDC: 0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee7e0d5ebb06f3ecf368a8
# USDT: 0x068f5c6a61780768455de69077e07e89787839bf8166decfbf92b645209c0fb8
df['Token0_name'] = ''
df['Token1_name'] = ''

address = '0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c741b1562b82f9e004dc7'
df.loc[df['TOKEN0_ADDRESS'] == address, 'Token0_name'] = 'ETH'

address = '0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee7e0d5ebb06f3ecf368a8'
df.loc[df['TOKEN0_ADDRESS'] == address, 'Token0_name'] = 'USDC'

address = '0x04718f5a0fc34cc1af16a1cdee98ffb20c31f5cd61d6ab07201858f4287c938d'
df.loc[df['TOKEN0_ADDRESS'] == address, 'Token0_name'] = 'STRK'

address = '0x049d36570d4e46f48e99674bd3fcc84644ddd6b96f7c741b1562b82f9e004dc7'
df.loc[df['TOKEN1_ADDRESS'] == address, 'Token1_name'] = 'ETH'

address = '0x053c91253bc9682c04929ca02ed00b3e423f6710d2ee7e0d5ebb06f3ecf368a8'
df.loc[df['TOKEN1_ADDRESS'] == address, 'Token1_name'] = 'USDC'

address = '0x068f5c6a61780768455de69077e07e89787839bf8166decfbf92b645209c0fb8'
df.loc[df['TOKEN1_ADDRESS'] == address, 'Token1_name'] = 'USDT'


# Convert each column to either int or float:
columns_int = ['BLOCK_NUMBER', 'TOKEN0_DECIMALS', 'TOKEN1_DECIMALS', 'TICK_SPACING']
df[columns_int] = df[columns_int].applymap(lambda x: int(x))

columns_float = ['TOKEN0_RAW_AMOUNT', 'TOKEN0_REAL_AMOUNT', 'TOKEN1_RAW_AMOUNT', 'TOKEN1_REAL_AMOUNT',
                 'FEE_TIER', 'LIQUIDITY_AMOUNT', 'LOWER_TICK', 'UPPER_TICK', 'SWAP_TICK']
df[columns_float] = df[columns_float].applymap(lambda x: float(x))


# Create a new 'tag' column
df['tag'] = df['Token0_name']+'_'+df['Token1_name']+'_'+df['EVENT_NAME']

# %%
# Show all tags for pair-pools
list_targets = df['tag'].unique()
list_targets.sort()
print(list_targets)
print('Total tags:', len(list_targets))
# Out:
# ['ETH_USDC_Burn' 'ETH_USDC_Mint' 'ETH_USDC_Swap' 'STRK_ETH_Burn'
#  'STRK_ETH_Mint' 'STRK_ETH_Swap' 'STRK_USDC_Burn' 'STRK_USDC_Mint'
#  'STRK_USDC_Swap' 'STRK_USDT_Burn' 'STRK_USDT_Mint' 'STRK_USDT_Swap'
#  'USDC_USDT_Burn' 'USDC_USDT_Mint' 'USDC_USDT_Swap']
# Total tags: 15

# %%
# Show % of rows for each tag among the whole dataset: 

# Create a dictionary to store outputs
tags_stat = {'tags':[], 'date_b':[], 'date_e':[], 'total_rows':[], 'percentage':[]}  

for tag in list_targets:
    print(tag)
    tags_stat['tags'].append(tag)
    
    df2 = df[df['tag']==tag]

    tags_stat['date_b'].append(df2['datetime'].iloc[0])
    tags_stat['date_e'].append(df2['datetime'].iloc[-1])

    tags_stat['total_rows'].append(len(df2))
    tags_stat['percentage'].append(round(len(df2)/len(df)*100,5))
    
    print('Data begin:', df2['datetime'].iloc[0])
    print('Data end:', df2['datetime'].iloc[-1])
    print('% of total rows in the dataset:',round(len(df2)/len(df)*100,5),'%')
    print('-------------------')

# Convert dictionary to a dataframe
df_stat = pd.DataFrame(tags_stat)
print('-------------------')
print(df_stat)
# Out:
# ETH_USDC_Burn
# Data begin: 2023-08-24 15:58:31
# Data end: 2024-02-25 03:56:42
# % of total rows in the dataset: 3.81504 %
# -------------------
# ETH_USDC_Mint
# Data begin: 2023-08-21 18:06:57
# Data end: 2024-02-25 03:56:09
# % of total rows in the dataset: 7.61054 %
# -------------------
# ETH_USDC_Swap
# Data begin: 2023-08-31 07:37:53
# Data end: 2024-02-25 03:57:43
# % of total rows in the dataset: 54.02446 %
# -------------------
# STRK_ETH_Burn
# Data begin: 2024-02-08 22:46:45
# Data end: 2024-02-25 03:56:24
# % of total rows in the dataset: 0.14818 %
# -------------------
# STRK_ETH_Mint
# Data begin: 2024-02-08 12:27:13
# Data end: 2024-02-25 03:57:26
# % of total rows in the dataset: 0.57397 %
# -------------------
# STRK_ETH_Swap
# Data begin: 2024-02-20 11:59:09
# Data end: 2024-02-25 03:56:42
# % of total rows in the dataset: 4.38071 %
# -------------------
# STRK_USDC_Burn
# Data begin: 2024-02-16 06:32:41
# Data end: 2024-02-25 03:55:49
# % of total rows in the dataset: 0.06205 %
# -------------------
# STRK_USDC_Mint
# Data begin: 2024-02-11 11:21:18
# Data end: 2024-02-25 03:57:07
# % of total rows in the dataset: 0.22673 %
# -------------------
# STRK_USDC_Swap
# Data begin: 2024-02-20 12:05:22
# Data end: 2024-02-25 03:57:26
# % of total rows in the dataset: 2.07228 %
# -------------------
# STRK_USDT_Burn
# Data begin: 2024-02-20 10:21:21
# Data end: 2024-02-25 00:31:10
# % of total rows in the dataset: 0.00188 %
# -------------------
# STRK_USDT_Mint
# Data begin: 2024-02-19 16:26:11
# Data end: 2024-02-24 23:43:20
# % of total rows in the dataset: 0.00397 %
# -------------------
# STRK_USDT_Swap
# Data begin: 2024-02-20 12:02:32
# Data end: 2024-02-25 03:36:21
# % of total rows in the dataset: 0.20448 %
# -------------------
# USDC_USDT_Burn
# Data begin: 2023-08-27 19:38:16
# Data end: 2024-02-25 03:57:26
# % of total rows in the dataset: 0.70829 %
# -------------------
# USDC_USDT_Mint
# Data begin: 2023-08-25 17:26:00
# Data end: 2024-02-25 03:49:36
# % of total rows in the dataset: 1.55769 %
# -------------------
# USDC_USDT_Swap
# Data begin: 2023-09-06 19:47:11
# Data end: 2024-02-25 03:56:09
# % of total rows in the dataset: 24.60974 %
# -------------------
# -------------------
#               tags              date_b              date_e  total_rows  \
# 0    ETH_USDC_Burn 2023-08-24 15:58:31 2024-02-25 03:56:42      115395
# 1    ETH_USDC_Mint 2023-08-21 18:06:57 2024-02-25 03:56:09      230199
# 2    ETH_USDC_Swap 2023-08-31 07:37:53 2024-02-25 03:57:43     1634100
# 3    STRK_ETH_Burn 2024-02-08 22:46:45 2024-02-25 03:56:24        4482
# 4    STRK_ETH_Mint 2024-02-08 12:27:13 2024-02-25 03:57:26       17361
# 5    STRK_ETH_Swap 2024-02-20 11:59:09 2024-02-25 03:56:42      132505
# 6   STRK_USDC_Burn 2024-02-16 06:32:41 2024-02-25 03:55:49        1877
# 7   STRK_USDC_Mint 2024-02-11 11:21:18 2024-02-25 03:57:07        6858
# 8   STRK_USDC_Swap 2024-02-20 12:05:22 2024-02-25 03:57:26       62681
# 9   STRK_USDT_Burn 2024-02-20 10:21:21 2024-02-25 00:31:10          57
# 10  STRK_USDT_Mint 2024-02-19 16:26:11 2024-02-24 23:43:20         120
# 11  STRK_USDT_Swap 2024-02-20 12:02:32 2024-02-25 03:36:21        6185
# 12  USDC_USDT_Burn 2023-08-27 19:38:16 2024-02-25 03:57:26       21424
# 13  USDC_USDT_Mint 2023-08-25 17:26:00 2024-02-25 03:49:36       47116
# 14  USDC_USDT_Swap 2023-09-06 19:47:11 2024-02-25 03:56:09      744381
#
#     percentage
# 0      3.81504
# 1      7.61054
# 2     54.02446
# 3      0.14818
# 4      0.57397
# 5      4.38071
# 6      0.06205
# 7      0.22673
# 8      2.07228
# 9      0.00188
# 10     0.00397
# 11     0.20448
# 12     0.70829
# 13     1.55769
# 14    24.60974

# %%
# Plot % of rows for each tag among the whole dataset: 
df_stat_sorted = df_stat.sort_values(by='percentage', ascending=False)

plt.figure(figsize=(10, 6))
bars = plt.bar(df_stat_sorted['tags'], df_stat_sorted['percentage'])
plt.xlabel('Tags')
plt.ylabel('Percentage')
plt.title('Percentage Distribution by Tags')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

for i, bar in enumerate(bars):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(df_stat_sorted['total_rows'].iloc[i]),
             ha='center', va='bottom')

plt.savefig('images/fig_01a_01_bar_plot.png', dpi=150)
